# %%
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Define your number range
numbers = list(range(1, 100))

# Create an empty list to hold your sets
sets = []

# Generate 15 sets, define the amount of playboards here
for _ in range(15):
    # Use random.sample to get a unique set of 16 numbers
    random_set = random.sample(numbers, 16)
    # Append this set to your list of sets
    sets.append(random_set)

# Print the sets
for i, set in enumerate(sets):
    print(f"Set {i+1}: {set}")
# Out:
# Set 1: [85, 3, 17, 50, 12, 74, 63, 29, 68, 81, 18, 24, 76, 41, 31, 98]
# Set 2: [48, 4, 22, 27, 40, 57, 30, 25, 50, 14, 99, 83, 65, 11, 19, 64]
# Set 3: [21, 53, 69, 70, 30, 90, 62, 65, 26, 83, 66, 28, 72, 17, 3, 29]
# Set 4: [86, 62, 71, 90, 97, 93, 24, 3, 21, 77, 20, 49, 63, 22, 37, 25]
# Set 5: [1, 54, 66, 4, 63, 9, 10, 19, 14, 34, 42, 20, 56, 18, 65, 6]
# Set 6: [40, 64, 85, 75, 48, 68, 58, 69, 19, 95, 41, 97, 92, 44, 59, 47]
# Set 7: [86, 44, 93, 39, 76, 12, 3, 41, 36, 84, 94, 60, 4, 67, 25, 10]
# Set 8: [3, 47, 62, 12, 41, 37, 94, 79, 4, 35, 56, 15, 66, 30, 91, 1]
# Set 9: [41, 2, 91, 37, 47, 98, 10, 94, 35, 70, 39, 52, 19, 89, 74, 40]
# Set 10: [93, 26, 66, 97, 95, 6, 74, 54, 72, 4, 35, 79, 34, 89, 40, 47]
# Set 11: [35, 34, 21, 93, 60, 40, 11, 54, 12, 65, 5, 42, 27, 58, 8, 22]
# Set 12: [52, 79, 41, 2, 14, 76, 99, 77, 55, 38, 48, 49, 1, 75, 44, 98]
# Set 13: [51, 82, 27, 38, 88, 55, 10, 2, 63, 99, 5, 22, 70, 71, 83, 3]
# Set 14: [47, 13, 74, 99, 41, 65, 18, 34, 57, 89, 98, 49, 19, 72, 52, 95]
# Set 15: [73, 35, 27, 52, 75, 53, 88, 19, 39, 51, 77, 44, 1, 94, 72, 61]

# %%
# Load the csv file into a pandas DataFrame. File needs to be in directory root.
df = pd.read_csv('songs.csv', delimiter=";")

# Convert the DataFrame to a dictionary for easy lookups
songs_dict = df.set_index('num').T.to_dict('list')

# Map the sets of numbers to songs
song_sets = [[songs_dict[num] for num in num_set] for num_set in sets]

# Print the song sets in a 4x4 grid format
for i, song_set in enumerate(song_sets):
    print(f"Set {i+1}:")
    for j in range(0, 16, 4):
        print(song_set[j:j+4])
    print()
# Out:
# Set 1:
# [['Krapulassa töihin', 'Seksihullut'], ['Foxey Lady', 'Jimi Hendrix'], ["Ain't Talkin' 'Bout Love", 'Van Halen'], ['All Star', 'Smash Mouth']]
# [['I Feel the Earth Move', 'Carole King'], ["I Think I'm Paranoid", 'Garbage'], ['Still D.R.E.', 'Dr. Dre'], ['Raining Blood', 'Slayer']]
# [['Niina', 'PMMP'], ['PA 2001', 'MC Taakibörsta'], ['Take Me Home, Country Roads', 'John Denver'], ['Dancing In the Dark', 'Bruce Springsteen']]
# [['Child Is My Name', 'Kemopetrol'], ['Peggy', 'Samuli Edelmann'], ['For Those About to Rock (We Salute You)', 'AC/DC'], ['Sierralla Nevadaan', 'Portion Boys']]
#
# Set 2:
# [['Enjoy the Silence', 'Depeche Mode'], ["Surfin' U.S.A.", 'The Beach Boys'], ['Poliisi Pamputtaa Taas', 'Eppu Normaali'], ['Tulkoon rakkaus', 'Miljoonasade']]
# [['Via Dolorosa', 'Tommi Läntinen'], ['Join Me - Razorblade Mix', 'HIM'], ['Cheri Cheri Lady', 'Modern Talking'], ['Älä itke, Baby Jane', 'Leevi and the leavings']]
# [['All Star', 'Smash Mouth'], ['Sweet Emotion', 'Aerosmith'], ['The Number of the Beast', 'Iron Maiden'], ['Vaarallinen bändi', 'Kissa']]
# [['Boom, Boom, Boom, Boom!!', 'Vengaboys'], ['Caroline', 'Status Quo'], ['Panomies', 'Juice Leskinen'], ["Drop It Like It's Hot", 'Snoop Dogg']]
#
# Set 3:
# [['Taas nousen junaan', 'Kirka'], ['All The Small Things', 'blink-182'], ['Merenneitoni Ja Minä', 'J. Karjalainen'], ['Take A Look Around', 'Limp Bizkit']]
# [['Cheri Cheri Lady', 'Modern Talking'], ['Lesbo', 'JJJ Experience'], ['Black and Yellow', 'Wiz Khalifa'], ['Boom, Boom, Boom, Boom!!', 'Vengaboys']]
# [['Kiss Me Deadly', 'Lita Ford'], ['Vaarallinen bändi', 'Kissa'], ['DotA - Radio Edit', 'Basshunter'], ['Äiti pojastaan pappia toivoi', 'Kolmas Nainen']]
# [['Jenny from the Block', 'Jennifer Lopez'], ["Ain't Talkin' 'Bout Love", 'Van Halen'], ['Foxey Lady', 'Jimi Hendrix'], ['Raining Blood', 'Slayer']]
#
# Set 4:
# [['Neiti B', 'Tamara Luonto'], ['Black and Yellow', 'Wiz Khalifa'], ['Liquid', 'The Rasmus'], ['Lesbo', 'JJJ Experience']]
# [['Better Off Alone', 'Alice Deejay'], ['Habits (Stay High)', 'Tove Lo'], ['Dancing In the Dark', 'Bruce Springsteen'], ['Foxey Lady', 'Jimi Hendrix']]
# [['Taas nousen junaan', 'Kirka'], ['Hellä ori', 'Lord Est'], ['Kurjuuden kuningas', 'Tuomari Nurmio'], ["Say You'll Be There", 'Spice Girls']]
# [['Still D.R.E.', 'Dr. Dre'], ['Poliisi Pamputtaa Taas', 'Eppu Normaali'], ['Paha tyttö', 'Muska'], ['Älä itke, Baby Jane', 'Leevi and the leavings']]
#
# Set 5:
# [["A Hard Day's Night", 'The Beatles'], ['The Chief', 'Melrose'], ['DotA - Radio Edit', 'Basshunter'], ["Surfin' U.S.A.", 'The Beach Boys']]
# [['Still D.R.E.', 'Dr. Dre'], ['King Of The Road', 'Roger Miller'], ['Superstition', 'Stevie Wonder'], ['Panomies', 'Juice Leskinen']]
# [['Sweet Emotion', 'Aerosmith'], ['Just Like Heaven', 'The Cure'], ['Kersantti Karoliina', 'Popeda'], ['Kurjuuden kuningas', 'Tuomari Nurmio']]
# [['N.Y. State of Mind', 'Nas'], ['Take Me Home, Country Roads', 'John Denver'], ['Boom, Boom, Boom, Boom!!', 'Vengaboys'], ['Somebody to Love', 'Jefferson Airplane']]
#
# Set 6:
# [['Via Dolorosa', 'Tommi Läntinen'], ["Drop It Like It's Hot", 'Snoop Dogg'], ['Krapulassa töihin', 'Seksihullut'], ['Time Is Now', 'Moloko']]
# [['Enjoy the Silence', 'Depeche Mode'], ['Niina', 'PMMP'], ['Mombasa', 'Taiska'], ['Merenneitoni Ja Minä', 'J. Karjalainen']]
# [['Panomies', 'Juice Leskinen'], ['Rokkilaulaja', 'Mikko Alatalo'], ['Peggy', 'Samuli Edelmann'], ['Better Off Alone', 'Alice Deejay']]
# [['Whole Lotta Love', 'Led Zeppelin'], ['All I Wanna Do', 'Sheryl Crow'], ["It Wasn't Me", 'Shaggy,Rik Rok'], ['Wonderwall', 'Oasis']]
#
# Set 7:
# [['Neiti B', 'Tamara Luonto'], ['All I Wanna Do', 'Sheryl Crow'], ['Habits (Stay High)', 'Tove Lo'], ['Hyvää yötä ja huomenta', 'Don Huonot']]
# [['Child Is My Name', 'Kemopetrol'], ['I Feel the Earth Move', 'Carole King'], ['Foxey Lady', 'Jimi Hendrix'], ['Peggy', 'Samuli Edelmann']]
# [['Asfaltti Polttaa', 'Tehosekoitin'], ['Näenkö näkyjä vain?', 'Joni Ekman'], ['Get On', 'Hurriganes'], ['All The Things She Said', 't.A.T.u.']]
# [["Surfin' U.S.A.", 'The Beach Boys'], ['This Is My Head Exploding', 'Disco Ensemble'], ['Älä itke, Baby Jane', 'Leevi and the leavings'], ['Superstition', 'Stevie Wonder']]
#
# Set 8:
# [['Foxey Lady', 'Jimi Hendrix'], ['Wonderwall', 'Oasis'], ['Black and Yellow', 'Wiz Khalifa'], ['I Feel the Earth Move', 'Carole King']]
# [['Peggy', 'Samuli Edelmann'], ['Paha tyttö', 'Muska'], ['Get On', 'Hurriganes'], ['Tyttö sinä olet meritähti', 'Yön Polte']]
# [["Surfin' U.S.A.", 'The Beach Boys'], ['Kemiaa', 'Neon 2'], ['N.Y. State of Mind', 'Nas'], ['Simple Man', 'Lynyrd Skynyrd']]
# [['DotA - Radio Edit', 'Basshunter'], ['Cheri Cheri Lady', 'Modern Talking'], ['Dokaa', 'Hitto'], ["A Hard Day's Night", 'The Beatles']]
#
# Set 9:
# [['Peggy', 'Samuli Edelmann'], ['Oh, Pretty Woman', 'Roy Orbison'], ['Dokaa', 'Hitto'], ['Paha tyttö', 'Muska']]
# [['Wonderwall', 'Oasis'], ['Sierralla Nevadaan', 'Portion Boys'], ['Superstition', 'Stevie Wonder'], ['Get On', 'Hurriganes']]
# [['Kemiaa', 'Neon 2'], ['Take A Look Around', 'Limp Bizkit'], ['Hyvää yötä ja huomenta', 'Don Huonot'], ['Pretty Fly (For A White Guy)', 'The Offspring']]
# [['Panomies', 'Juice Leskinen'], ['Koulutuskusetus', 'Langettava Päätös'], ["I Think I'm Paranoid", 'Garbage'], ['Via Dolorosa', 'Tommi Läntinen']]
#
# Set 10:
# [['Habits (Stay High)', 'Tove Lo'], ['Kiss Me Deadly', 'Lita Ford'], ['DotA - Radio Edit', 'Basshunter'], ['Better Off Alone', 'Alice Deejay']]
# [['Rokkilaulaja', 'Mikko Alatalo'], ['Somebody to Love', 'Jefferson Airplane'], ["I Think I'm Paranoid", 'Garbage'], ['The Chief', 'Melrose']]
# [['Jenny from the Block', 'Jennifer Lopez'], ["Surfin' U.S.A.", 'The Beach Boys'], ['Kemiaa', 'Neon 2'], ['Tyttö sinä olet meritähti', 'Yön Polte']]
# [['Just Like Heaven', 'The Cure'], ['Koulutuskusetus', 'Langettava Päätös'], ['Via Dolorosa', 'Tommi Läntinen'], ['Wonderwall', 'Oasis']]
#
# Set 11:
# [['Kemiaa', 'Neon 2'], ['Just Like Heaven', 'The Cure'], ['Taas nousen junaan', 'Kirka'], ['Habits (Stay High)', 'Tove Lo']]
# [['All The Things She Said', 't.A.T.u.'], ['Via Dolorosa', 'Tommi Läntinen'], ['Caroline', 'Status Quo'], ['The Chief', 'Melrose']]
# [['I Feel the Earth Move', 'Carole King'], ['Boom, Boom, Boom, Boom!!', 'Vengaboys'], ['On The Road Again', 'Canned Heat'], ['Kersantti Karoliina', 'Popeda']]
# [['Tulkoon rakkaus', 'Miljoonasade'], ['Mombasa', 'Taiska'], ['Bad Moon Rising', 'Creedence Clearwater Revival'], ['Poliisi Pamputtaa Taas', 'Eppu Normaali']]
#
# Set 12:
# [['Pretty Fly (For A White Guy)', 'The Offspring'], ['Tyttö sinä olet meritähti', 'Yön Polte'], ['Peggy', 'Samuli Edelmann'], ['Oh, Pretty Woman', 'Roy Orbison']]
# [['Sweet Emotion', 'Aerosmith'], ['Child Is My Name', 'Kemopetrol'], ['The Number of the Beast', 'Iron Maiden'], ['Hellä ori', 'Lord Est']]
# [['The Ballad Of Chasey Lain', 'Bloodhound Gang'], ['Älä soita tänne enää koskaan', 'Ultra Bra'], ['Enjoy the Silence', 'Depeche Mode'], ["Say You'll Be There", 'Spice Girls']]
# [["A Hard Day's Night", 'The Beatles'], ['Time Is Now', 'Moloko'], ['All I Wanna Do', 'Sheryl Crow'], ['Sierralla Nevadaan', 'Portion Boys']]
#
# Set 13:
# [['Zombie', 'The Cranberries'], ['Landespede', 'Kemmuru'], ['Tulkoon rakkaus', 'Miljoonasade'], ['Älä soita tänne enää koskaan', 'Ultra Bra']]
# [['Älä mee siihen taloon joka palaa', 'Mara Balls'], ['The Ballad Of Chasey Lain', 'Bloodhound Gang'], ['Superstition', 'Stevie Wonder'], ['Oh, Pretty Woman', 'Roy Orbison']]
# [['Still D.R.E.', 'Dr. Dre'], ['The Number of the Beast', 'Iron Maiden'], ['On The Road Again', 'Canned Heat'], ['Poliisi Pamputtaa Taas', 'Eppu Normaali']]
# [['Take A Look Around', 'Limp Bizkit'], ['Liquid', 'The Rasmus'], ['Vaarallinen bändi', 'Kissa'], ['Foxey Lady', 'Jimi Hendrix']]
#
# Set 14:
# [['Wonderwall', 'Oasis'], ['Paranoid', 'Black Sabbath'], ["I Think I'm Paranoid", 'Garbage'], ['The Number of the Beast', 'Iron Maiden']]
# [['Peggy', 'Samuli Edelmann'], ['Boom, Boom, Boom, Boom!!', 'Vengaboys'], ['Take Me Home, Country Roads', 'John Denver'], ['Just Like Heaven', 'The Cure']]
# [['Join Me - Razorblade Mix', 'HIM'], ['Koulutuskusetus', 'Langettava Päätös'], ['Sierralla Nevadaan', 'Portion Boys'], ["Say You'll Be There", 'Spice Girls']]
# [['Panomies', 'Juice Leskinen'], ['Jenny from the Block', 'Jennifer Lopez'], ['Pretty Fly (For A White Guy)', 'The Offspring'], ['Rokkilaulaja', 'Mikko Alatalo']]
#
# Set 15:
# [['Tarkenee', 'JVG'], ['Kemiaa', 'Neon 2'], ['Tulkoon rakkaus', 'Miljoonasade'], ['Pretty Fly (For A White Guy)', 'The Offspring']]
# [['Time Is Now', 'Moloko'], ['All The Small Things', 'blink-182'], ['Älä mee siihen taloon joka palaa', 'Mara Balls'], ['Panomies', 'Juice Leskinen']]
# [['Hyvää yötä ja huomenta', 'Don Huonot'], ['Zombie', 'The Cranberries'], ['Hellä ori', 'Lord Est'], ['All I Wanna Do', 'Sheryl Crow']]
# [["A Hard Day's Night", 'The Beatles'], ['Get On', 'Hurriganes'], ['Jenny from the Block', 'Jennifer Lopez'], ['Perhonen', 'Jane']]

# %%
# Select only the artist name for each song, and include the index number
artist_sets = [[f"{num}.\n {song[1]}" for num, song in zip(sets[i], song_set)] for i, song_set in enumerate(song_sets)]

# Create the grids and save them as .jpg files
for i, song_set in enumerate(artist_sets):
    # Convert each set into a 4x4 numpy array for easy visualization
    artist_grid = np.array(song_set).reshape(4, 4)

    # Create a figure and axis
    fig, ax = plt.subplots()

    # Remove x and y axis
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)

    # Turn off the frame
    ax.set_frame_on(False)

    # Create a table and fill it with the artists
    tbl = plt.table(cellText=artist_grid, cellLoc = 'center', loc='center', bbox=[0, 0, 1, 1])

    # Set the fontsize to fit the artists nicely into the cells
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(8)

    # Save the figure as a .jpg file
    plt.savefig(f"Set_{i+1}.jpg")

# %%
# Select only the song name for each song, and include the index number
song_sets = [[f"{num}.\n {song[0]}" for num, song in zip(sets[i], song_set)] for i, song_set in enumerate(song_sets)]

# Create the grids and save them as .jpg files
for i, song_set in enumerate(song_sets):
    # Convert each set into a 4x4 numpy array for easy visualization
    song_grid = np.array(song_set).reshape(4, 4)

    # Create a figure and axis
    fig, ax = plt.subplots()

    # Remove x and y axis
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)

    # Turn off the frame
    ax.set_frame_on(False)

    # Create a table and fill it with the song names
    tbl = plt.table(cellText=song_grid, cellLoc = 'center', loc='center', bbox=[0, 0, 1, 1])

    # Set the fontsize to fit the song names nicely into the cells
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(6)

    # Save the figure as a .jpg file
    plt.savefig(f"Song_Set_{i+1}.jpg")
