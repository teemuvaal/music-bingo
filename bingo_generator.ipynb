# %%
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Define your number range
numbers = list(range(1, 100))

# Create an empty list to hold your sets
sets = []

# Generate 10 sets
for _ in range(10):
    # Use random.sample to get a unique set of 16 numbers
    random_set = random.sample(numbers, 16)
    # Append this set to your list of sets
    sets.append(random_set)

# Print the sets
for i, set in enumerate(sets):
    print(f"Set {i+1}: {set}")

# %%
# Load the csv file into a pandas DataFrame. File needs to be in directory root.
df = pd.read_csv('songs.csv', delimiter=";")

# Convert the DataFrame to a dictionary for easy lookups
songs_dict = df.set_index('num').T.to_dict('list')

# Map the sets of numbers to songs
song_sets = [[songs_dict[num] for num in num_set] for num_set in sets]

# Print the song sets in a 4x4 grid format
for i, song_set in enumerate(song_sets):
    print(f"Set {i+1}:")
    for j in range(0, 16, 4):
        print(song_set[j:j+4])
    print()
# Out:
# Set 1:
# [['White Room', 'Cream'], ['Wonderwall - Remastered', 'Oasis'], ['Kippis Kulaus', 'Petri Nygård'], ['Take Me Home, Country Roads', 'John Denver']]
# [['Zombie', 'The Cranberries'], ['Cheri Cheri Lady', 'Modern Talking'], ['Boom, Boom, Boom, Boom!!', 'Vengaboys'], ['Rock And Roll All Nite', 'KISS']]
# [['Krapulassa töihin', 'Seksihullut'], ["Ain't Talkin' 'Bout Love - 2015 Remaster", 'Van Halen'], ['Näenkö näkyjä vain?', 'Joni Ekman'], ['The Chief', 'Melrose']]
# [['Somebody to Love', 'Jefferson Airplane'], ['Taas nousen junaan', 'Kirka'], ['Stigidilaatio', 'Stig Dogg,DJPP'], ['Hellä ori (feat. Mariska)', 'Lord Est,Mariska']]
#
# Set 2:
# [["A Hard Day's Night - Remastered 2009", 'The Beatles'], ['Asfaltti Polttaa', 'Tehosekoitin'], ['Kippis Kulaus', 'Petri Nygård'], ['Älä soita tänne enää koskaan', 'Ultra Bra']]
# [['Via Dolorosa', 'Tommi Läntinen'], ['I Feel the Earth Move', 'Carole King'], ['Battles in the North', 'Immortal'], ['On The Road Again', 'Canned Heat']]
# [['Koulutuskusetus', 'Langettava Päätös'], ["Blue Monday '88", 'New Order'], ['Join Me - Razorblade Mix', 'HIM'], ['Zombie', 'The Cranberries']]
# [['Jenny from the Block (feat. Jadakiss & Styles P.) - Track Masters Remix', 'Jennifer Lopez,Jadakiss,Styles P'], ['Oh, Pretty Woman', 'Roy Orbison'], ['For Those About to Rock (We Salute You)', 'AC/DC'], ['Paha tyttö', 'Muska']]
#
# Set 3:
# [['PA 2001 (ft. Didier)', 'MC Taakibörsta'], ['Paha tyttö', 'Muska'], ["I Think I'm Paranoid - 2018 - Remaster", 'Garbage'], ['The Chief', 'Melrose']]
# [['Just Like Heaven', 'The Cure'], ['Kurjuuden kuningas', 'Tuomari Nurmio,Köyhien Ystävät'], ['Landespede', 'Kemmuru'], ['Älä itke, Baby Jane', 'Leevi and the leavings']]
# [['Lesbo', 'JJJ Experience'], ['Sweet Emotion', 'Aerosmith'], ['Boom, Boom, Boom, Boom!!', 'Vengaboys'], ['You Oughta Know - 2015 Remaster', 'Alanis Morissette']]
# [['Merenneitoni Ja Minä', 'J. Karjalainen & Mustat Lasit'], ['Neiti B', 'Tamara Luonto'], ['Child Is My Name', 'Kemopetrol'], ['Caroline', 'Status Quo']]
#
# Set 4:
# [['Liquid', 'The Rasmus'], ['Älä itke, Baby Jane', 'Leevi and the leavings'], ['Child Is My Name', 'Kemopetrol'], ['Cheri Cheri Lady', 'Modern Talking']]
# [['Paha tyttö', 'Muska'], ["Surfin' U.S.A. - Remastered 2001", 'The Beach Boys'], ['Simple Man', 'Lynyrd Skynyrd'], ['Lesbo', 'JJJ Experience']]
# [['Hyvää yötä ja huomenta', 'Don Huonot'], ['Join Me - Razorblade Mix', 'HIM'], ["Say You'll Be There", 'Spice Girls'], ["Drop It Like It's Hot", 'Snoop Dogg,Pharrell Williams']]
# [['Koulutuskusetus', 'Langettava Päätös'], ['DotA - Radio Edit', 'Basshunter'], ['Krapulassa töihin', 'Seksihullut'], ['Somebody to Love', 'Jefferson Airplane']]
#
# Set 5:
# [['Hyvää yötä ja huomenta', 'Don Huonot'], ['Wonderwall - Remastered', 'Oasis'], ['Oh, Pretty Woman', 'Roy Orbison'], ['Peggy', 'Samuli Edelmann']]
# [['Still D.R.E.', 'Dr. Dre,Snoop Dogg'], ['All I Wanna Do', 'Sheryl Crow'], ["Surfin' U.S.A. - Remastered 2001", 'The Beach Boys'], ['Älä mee siihen taloon joka palaa', 'Mara Balls']]
# [['Rock And Roll All Nite', 'KISS'], ['DotA - Radio Edit', 'Basshunter'], ['Liquid', 'The Rasmus'], ['Take Me Home, Country Roads', 'John Denver']]
# [['You Oughta Know - 2015 Remaster', 'Alanis Morissette'], ['Kiss Me Deadly', 'Lita Ford'], ['Dancing In the Dark', 'Bruce Springsteen'], ['Vaarallinen bändi', 'Kissa']]
#
# Set 6:
# [['Somebody to Love', 'Jefferson Airplane'], ['Tulkoon rakkaus', 'Miljoonasade'], ['Wonderwall - Remastered', 'Oasis'], ["Say You'll Be There", 'Spice Girls']]
# [['The Chief', 'Melrose'], ['Älä mee siihen taloon joka palaa', 'Mara Balls'], ['Poliisi Pamputtaa Taas', 'Eppu Normaali'], ['All The Things She Said', 't.A.T.u.']]
# [['Kurjuuden kuningas', 'Tuomari Nurmio,Köyhien Ystävät'], ['Pizzaa Ja Kaljaa', 'Rock Siltanen Group'], ['Take Me Home, Country Roads', 'John Denver'], ['This Is My Head Exploding', 'Disco Ensemble']]
# [['Foxey Lady', 'Jimi Hendrix'], ['Peggy', 'Samuli Edelmann'], ['Pretty Fly (For A White Guy)', 'The Offspring'], ['Raining Blood', 'Slayer']]
#
# Set 7:
# [["I Think I'm Paranoid - 2018 - Remaster", 'Garbage'], ['All The Small Things', 'blink-182'], ['Caroline', 'Status Quo'], ['Poliisi Pamputtaa Taas', 'Eppu Normaali']]
# [['Älä mee siihen taloon joka palaa', 'Mara Balls'], ['Krapulassa töihin', 'Seksihullut'], ['Mombasa', 'Taiska'], ['Tulkoon rakkaus', 'Miljoonasade']]
# [['Älä soita tänne enää koskaan', 'Ultra Bra'], ['Paha tyttö', 'Muska'], ['Kurjuuden kuningas', 'Tuomari Nurmio,Köyhien Ystävät'], ['Hyvää yötä ja huomenta', 'Don Huonot']]
# [['Tarkenee', 'JVG'], ["Surfin' U.S.A. - Remastered 2001", 'The Beach Boys'], ['Bad Moon Rising', 'Creedence Clearwater Revival'], ["Let's Dance - 2018 Remaster", 'David Bowie']]
#
# Set 8:
# [['The Chief', 'Melrose'], ['Kemiaa', 'Neon 2'], ['Boom, Boom, Boom, Boom!!', 'Vengaboys'], ['Mombasa', 'Taiska']]
# [["It Wasn't Me", 'Shaggy,Rik Rok'], ['Via Dolorosa', 'Tommi Läntinen'], ['Paranoid', 'Black Sabbath'], ['Take A Look Around', 'Limp Bizkit']]
# [['Tulkoon rakkaus', 'Miljoonasade'], ['Sweet Emotion', 'Aerosmith'], ['Neiti B', 'Tamara Luonto'], ['Krapulassa töihin', 'Seksihullut']]
# [['Battles in the North', 'Immortal'], ['Zombie', 'The Cranberries'], ["A Hard Day's Night - Remastered 2009", 'The Beatles'], ['Simple Man', 'Lynyrd Skynyrd']]
#
# Set 9:
# [['Tarkenee', 'JVG'], ['Kiss Me Deadly', 'Lita Ford'], ['Mombasa', 'Taiska'], ['Tulkoon rakkaus', 'Miljoonasade']]
# [['Via Dolorosa', 'Tommi Läntinen'], ['Kemiaa', 'Neon 2'], ['Cheri Cheri Lady', 'Modern Talking'], ['Nti Groove', 'Aikakone']]
# [['I Feel the Earth Move', 'Carole King'], ['Taas nousen junaan', 'Kirka'], ['Oh, Pretty Woman', 'Roy Orbison'], ['Merenneitoni Ja Minä', 'J. Karjalainen & Mustat Lasit']]
# [['Landespede', 'Kemmuru'], ["Blue Monday '88", 'New Order'], ['Kippis Kulaus', 'Petri Nygård'], ['Hyvää yötä ja huomenta', 'Don Huonot']]
#
# Set 10:
# [['Boom, Boom, Boom, Boom!!', 'Vengaboys'], ['Poliisi Pamputtaa Taas', 'Eppu Normaali'], ['N.Y. State of Mind', 'Nas'], ['All I Wanna Do', 'Sheryl Crow']]
# [['Liquid', 'The Rasmus'], ['Black and Yellow', 'Wiz Khalifa'], ['Vaarallinen bändi', 'Kissa'], ['Näenkö näkyjä vain?', 'Joni Ekman']]
# [["Blue Monday '88", 'New Order'], ['Paha tyttö', 'Muska'], ['Bad Moon Rising', 'Creedence Clearwater Revival'], ['Taas nousen junaan', 'Kirka']]
# [['Just Like Heaven', 'The Cure'], ['Oh, Pretty Woman', 'Roy Orbison'], ['Caroline', 'Status Quo'], ['Take Me Home, Country Roads', 'John Denver']]

# %%
# Create the grids and save them as .jpg files
for i, song_set in enumerate(artist_sets):
    # Convert each set into a 4x4 numpy array for easy visualization
    artist_grid = np.array(song_set).reshape(4, 4)

    # Create a figure and axis
    fig, ax = plt.subplots()

    # Remove x and y axis
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)

    # Turn off the frame
    ax.set_frame_on(False)

    # Create a table and fill it with the artists
    tbl = plt.table(cellText=artist_grid, cellLoc = 'center', loc='center', bbox=[0, 0, 1, 1])

    # Set the fontsize to fit the artists nicely into the cells
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(8)

    # Save the figure as a .jpg file
    plt.savefig(f"Set_{i+1}.jpg")
